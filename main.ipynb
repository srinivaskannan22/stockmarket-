# %%
import requests

data=requests.get('http://alphavaqntage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&outputsize=full&apikey=demo')

# %%
response=data.json()

# %%
len(response['Time Series (5min)'])
# Out:
# 3584

# %%
x=data.data
y=data.target

# %%
data.feature_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import pandas as pd 
data=pd.DataFrame(x,columns=data.feature_names)

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
target=pd.Series(y,name='target')

# %%
data=pd.concat([data,target],axis=1)

# %%
data.to_csv('irisdata.csv')

# %%
import boto3
client=boto3.client('s3')

# %%
client.upload_file("/Users/bootlabs/stock_price/irisdata.csv","uploaddata213","iris.csv")

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
import pandas as pd

pd.DataFrame(response['Time Series (5min)'])
# Out:
#           2025-06-06 19:55:00 2025-06-06 19:50:00 2025-06-06 19:45:00  \
# 1. open              268.9900            268.9900            268.9964
# 2. high              268.9900            268.9900            268.9964
# 3. low               268.9900            268.9900            268.9964
# 4. close             268.9900            268.9900            268.9964
# 5. volume                   3                  10                  14
#
#           2025-06-06 19:20:00 2025-06-06 19:10:00 2025-06-06 19:00:00  \
# 1. open              268.5700            268.9995            268.8700
# 2. high              268.5700            268.9995            268.8700
# 3. low               268.5700            268.9995            268.8700
# 4. close             268.5700            268.9995            268.8700
# 5. volume                  15                 100              399917
#
#           2025-06-06 18:55:00 2025-06-06 18:45:00 2025-06-06 18:35:00  \
# ...
